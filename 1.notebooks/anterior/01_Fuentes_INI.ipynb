# %% [markdown]
# ### 01_Fuentes.ipynb:
# Este notebook se enfoca en la adquisición e inspección inicial de los datos. El objetivo es cargar el archivo **"quejas-clientes.csv"** y realizar una primera exploración para entender su estructura, tipos de datos y la cantidad de filas y columnas.
#
# Como alternativa a los datos faltantes vamos a incorporar otras fuentes con las que podamos realizar la imputación de los mismos:
#
# 1.En la WEB con el siguiente enlace obtenemos un **"zip_code_database.csv"** de los Zip-codes de US: https://www.zip-codes.com
#
# El código ZIP (de la sigla en inglés "Zoning Improvement Plan") es un código postal que sirve para identificar áreas geográficas con fines de entrega de correo. Un código FIPS (de la sigla en inglés "Federal Information Processing Standard") es un código numérico utilizado por el gobierno de EE. UU. para identificar de manera única estados, condados y otras subdivisiones geográficas.

# %%
# Importamos librerías
import pandas as pd
import numpy as np
import os

# from ydata_profiling import ProfileReport
# from skrub import TableReport

# Ignoramos los warnings
import warnings
warnings.filterwarnings("ignore")

# %%
print(os.getcwd())
# Out:
# c:\Users\aisat\Desktop\DSPT25_RA\3-DSPT2025-ML\Proy_Final_ML_RA\1.notebooks

# %%
path_data= "C:/Users/aisat/Desktop/DSPT25_RA/3-DSPT2025-ML/Proy_Final_ML_RA/data/"

# %%
# 1. Cargar el archivo CSV
print ("Cargando el archivo 'quejas-clientes.csv'...")
try:
    df = pd.read_csv (path_data + 'quejas-clientes.csv', sep=",", encoding='utf-8')
    print ("¡Archivo cargado exitosamente!\n")
except FileNotFoundError:
    print ("Error: El archivo 'quejas-clientes.csv' no se encuentra en el directorio.")
except Exception as e:
    print (f"Error al cargar el archivo: {e}")
# Out:
# Cargando el archivo 'quejas-clientes.csv'...
# ¡Archivo cargado exitosamente!

# %%
# Mostrar las primeras 5 filas del DataFrame
df.head()
# Out:
#    Unnamed: 0  Complaint ID          Product               Sub-product  \
# 0           0       1291006  Debt collection                       NaN
# 1           1       1290580  Debt collection                   Medical
# 2           2       1290564         Mortgage              FHA mortgage
# 3           3       1291615      Credit card                       NaN
# 4           4       1292165  Debt collection  Non-federal student loan
#
#                                       Issue  \
# 0                     Communication tactics
# 1     Cont'd attempts collect debt not owed
# 2  Application, originator, mortgage broker
# 3                                     Other
# 4     Cont'd attempts collect debt not owed
#
#                            Sub-issue State  ZIP code Date received  \
# 0         Frequent or repeated calls    TX   76119.0    2015-03-19
# 1                   Debt is not mine    TX   77479.0    2015-03-19
# 2                                NaN    MA    2127.0    2015-03-19
# 3                                NaN    CA   92592.0    2015-03-19
# 4  Debt resulted from identity theft   NaN   43068.0    2015-03-19
#
#   Date sent to company                               Company  \
# 0           2015-03-19           Premium Asset Services, LLC
# 1           2015-03-19  Accounts Receivable Consultants Inc.
# 2           2015-03-19                          RBS Citizens
# 3           2015-03-19                              Navy FCU
# 4           2015-03-19               Transworld Systems Inc.
#
#           Company response Timely response? Consumer disputed?
# 0              In progress              Yes                NaN
# 1  Closed with explanation              Yes                NaN
# 2  Closed with explanation              Yes                Yes
# 3              In progress              Yes                NaN
# 4              In progress              Yes                NaN

# %%
# Eliminamos las filas duplicadas en el dataframe
df = df.drop_duplicates()

# %%
# Aplicamos el formato datetime a las columnas con fechas.
df['Date received'] = pd.to_datetime(df['Date received'], dayfirst=False)
df['Date sent to company'] = pd.to_datetime(df['Date sent to company'], dayfirst=False)

# %%
# Mostrar información general del DataFrame (tipos de datos, valores no nulos)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28156 entries, 0 to 28155
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            28156 non-null  int64
#  1   Complaint ID          28156 non-null  int64
#  2   Product               28156 non-null  object
#  3   Sub-product           17582 non-null  object
#  4   Issue                 28154 non-null  object
#  5   Sub-issue             13211 non-null  object
#  6   State                 27735 non-null  object
#  7   ZIP code              27876 non-null  float64
#  8   Date received         28156 non-null  datetime64[ns]
#  9   Date sent to company  28156 non-null  datetime64[ns]
#  10  Company               28156 non-null  object
#  11  Company response      28156 non-null  object
#  12  Timely response?      28156 non-null  object
#  13  Consumer disputed?    6006 non-null   object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 3.0+ MB

# %%
# Mostrar los valores faltantes en las diferentes variables del DataFrame
print (df.isnull().sum())
print ("-" * 30)
# Out:
# Unnamed: 0                  0
# Complaint ID                0
# Product                     0
# Sub-product             10574
# Issue                       2
# Sub-issue               14945
# State                     421
# ZIP code                  280
# Date received               0
# Date sent to company        0
# Company                     0
# Company response            0
# Timely response?            0
# Consumer disputed?      22150
# dtype: int64
# ------------------------------

# %% [markdown]
# Con el archivo quejas-clientes.csv, podemos abordar un problema de clasificación supervisada. El objetivo es predecir si un consumidor disputará la respuesta de una empresa a su queja. Esto es un problema de clasificación binaria, donde la variable objetivo es la columna Consumer disputed? con valores Yes o No.

# %%
# Revisión de la variable objetivo
# La variable objetivo es 'Consumer disputed?'
print("\nAnálisis de la variable objetivo 'Consumer disputed?':")
print(df['Consumer disputed?'].value_counts(dropna=False))
print("\nObservaciones sobre la variable objetivo:")
print("'Consumer disputed?': Los valores NaN probablemente representan quejas que no fueron disputadas.\
 Habrá que tratarlos en la limpieza de datos.")
# Out:
# Análisis de la variable objetivo 'Consumer disputed?':
# Consumer disputed?
# NaN    22150
# Yes     4708
# No      1298
# Name: count, dtype: int64
#
# Observaciones sobre la variable objetivo:
# 'Consumer disputed?': Los valores NaN probablemente representan quejas que no fueron disputadas. Habrá que tratarlos en la limpieza de datos.

# %%
# Guardamos el archivo df.csv
df.to_csv(path_data + 'df.csv', index=False, header=True)
df.head()
# Out:
#    Unnamed: 0  Complaint ID          Product               Sub-product  \
# 0           0       1291006  Debt collection                       NaN
# 1           1       1290580  Debt collection                   Medical
# 2           2       1290564         Mortgage              FHA mortgage
# 3           3       1291615      Credit card                       NaN
# 4           4       1292165  Debt collection  Non-federal student loan
#
#                                       Issue  \
# 0                     Communication tactics
# 1     Cont'd attempts collect debt not owed
# 2  Application, originator, mortgage broker
# 3                                     Other
# 4     Cont'd attempts collect debt not owed
#
#                            Sub-issue State  ZIP code Date received  \
# 0         Frequent or repeated calls    TX   76119.0    2015-03-19
# 1                   Debt is not mine    TX   77479.0    2015-03-19
# 2                                NaN    MA    2127.0    2015-03-19
# 3                                NaN    CA   92592.0    2015-03-19
# 4  Debt resulted from identity theft   NaN   43068.0    2015-03-19
#
#   Date sent to company                               Company  \
# 0           2015-03-19           Premium Asset Services, LLC
# 1           2015-03-19  Accounts Receivable Consultants Inc.
# 2           2015-03-19                          RBS Citizens
# 3           2015-03-19                              Navy FCU
# 4           2015-03-19               Transworld Systems Inc.
#
#           Company response Timely response? Consumer disputed?
# 0              In progress              Yes                NaN
# 1  Closed with explanation              Yes                NaN
# 2  Closed with explanation              Yes                Yes
# 3              In progress              Yes                NaN
# 4              In progress              Yes                NaN

# %%
# Conclusión
print ("\n--- Conclusión de 01_Fuentes.ipynb ---")
print ("El archivo CSV ha sido cargado e inspeccionado. Se han identificado la variable objetivo 'Consumer disputed?' y las columnas disponibles." \
"\nEl próximo paso es la limpieza y el análisis exploratorio de datos.")
# Out:
# --- Conclusión de 01_Fuentes.ipynb ---
# El archivo CSV ha sido cargado e inspeccionado. Se han identificado la variable objetivo 'Consumer disputed?' y las columnas disponibles.
# El próximo paso es la limpieza y el análisis exploratorio de datos.

# %%
# Un pequeño reporte de las columnas, con sus tipos, % de missings y cardinalidad, resultará muy útil a lo largo de la analítica.
def data_report(df):
    # Sacamos los NOMBRES
    cols = pd.DataFrame(df.columns.values, columns=["COL_N"])

    # Sacamos los TIPOS
    types = pd.DataFrame(df.dtypes.values, columns=["DATA_TYPE"])

    # Sacamos los MISSINGS
    percent_missing = round(df.isnull().sum() * 100 / len(df), 2)
    percent_missing_df = pd.DataFrame(percent_missing.values, columns=["MISSINGS (%)"])

    # Sacamos los VALORES UNICOS
    unicos = pd.DataFrame(df.nunique().values, columns=["UNIQUE_VALUES"])
    
    percent_cardin = round(unicos['UNIQUE_VALUES']*100/len(df), 2)
    percent_cardin_df = pd.DataFrame(percent_cardin.values, columns=["CARDIN (%)"])

    concatenado = pd.concat([cols, types, percent_missing_df, unicos, percent_cardin_df], axis=1, sort=False)
    concatenado.set_index('COL_N', drop=True, inplace=True)

    return concatenado.T
        
data_report(df)
# Out:
# COL_N         Unnamed: 0 Complaint ID Product Sub-product   Issue Sub-issue  \
# DATA_TYPE          int64        int64  object      object  object    object
# MISSINGS (%)         0.0          0.0     0.0       37.56    0.01     53.08
# UNIQUE_VALUES      28156        28156      11          42      89        46
# CARDIN (%)         100.0        100.0    0.04        0.15    0.32      0.16
#
# COL_N           State ZIP code   Date received Date sent to company Company  \
# DATA_TYPE      object  float64  datetime64[ns]       datetime64[ns]  object
# MISSINGS (%)      1.5     0.99             0.0                  0.0     0.0
# UNIQUE_VALUES      59     9868              78                   78    1534
# CARDIN (%)       0.21    35.05            0.28                 0.28    5.45
#
# COL_N         Company response Timely response? Consumer disputed?
# DATA_TYPE               object           object             object
# MISSINGS (%)               0.0              0.0              78.67
# UNIQUE_VALUES                6                2                  2
# CARDIN (%)                0.02             0.01               0.01

# %% [markdown]
# Analizamos los elementos más frecuentes de las diferentes columnas/variables numéricas y categóricas.

# %%
# Crearemos un informe para cada variable del dataframe, ordenados de forma descendente y %, número de valores unicos y datos faltantes.
def variable_report(df):
    for variable in df.columns:
        columna_original = variable
        # 1. Obtener la frecuencia de cada elemento único y ordenar de forma descendente
        conteo_elementos = df[columna_original].value_counts()

        # 2. Calcular el porcentaje de cada elemento
        porcentaje = df[columna_original].value_counts(normalize=True) * 100

        # 3. Formatear el porcentaje a 2 decimales
        porcentaje_formateado = porcentaje.map('{:.2f}%'.format)

        # 4. Crear un nuevo DataFrame con la información
        df_resultado = pd.DataFrame({
            columna_original: conteo_elementos.index,
            'Frecuencia': conteo_elementos.values,
            'Porcentaje': porcentaje_formateado.values
        })
        print (df_resultado.head(12), "\n")
        print ("Número de datos únicos", len(df[columna_original].sort_values(ascending=True).unique()))
        print ("Número de datos faltantes", len(df[df[columna_original].isna()]),"\n", "-" * 50)

# %%
# Ejecutamos la función "variable_report" para nuestro DataFrame
variable_report(df)
# Out:
#     Unnamed: 0  Frecuencia Porcentaje
# 0        28155           1      0.00%
# 1            0           1      0.00%
# 2            1           1      0.00%
# 3            2           1      0.00%
# 4            3           1      0.00%
# 5            4           1      0.00%
# 6            5           1      0.00%
# 7            6           1      0.00%
# 8            7           1      0.00%
# 9            8           1      0.00%
# 10           9           1      0.00%
# 11          10           1      0.00%
#
# Número de datos únicos 28156
# Número de datos faltantes 0
#  --------------------------------------------------
#     Complaint ID  Frecuencia Porcentaje
# 0        1178180           1      0.00%
# 1        1291006           1      0.00%
# 2        1290580           1      0.00%
# 3        1290564           1      0.00%
# 4        1291615           1      0.00%
# 5        1292165           1      0.00%
# 6        1291176           1      0.00%
# 7        1288848           1      0.00%
# 8        1288788           1      0.00%
# 9        1288324           1      0.00%
# 10       1288304           1      0.00%
# 11       1289772           1      0.00%
#
# Número de datos únicos 28156
# Número de datos faltantes 0
#  --------------------------------------------------
#                     Product  Frecuencia Porcentaje
# 0           Debt collection        7494     26.62%
# 1                  Mortgage        6612     23.48%
# 2          Credit reporting        5717     20.30%
# 3               Credit card        2830     10.05%
# 4   Bank account or service        2609      9.27%
# 5             Consumer loan        1314      4.67%
# 6              Student loan         785      2.79%
# 7               Payday loan         348      1.24%
# 8           Money transfers         232      0.82%
# 9              Prepaid card         175      0.62%
# 10  Other financial service          40      0.14%
#
# Número de datos únicos 11
# Número de datos faltantes 0
#  --------------------------------------------------
#                                Sub-product  Frecuencia Porcentaje
# 0              Conventional fixed mortgage        2446     13.91%
# 1         Other (phone, health club, etc.)        2273     12.93%
# 2                           Other mortgage        1954     11.11%
# 3                         Checking account        1693      9.63%
# 4                              Credit card        1447      8.23%
# 5                                  Medical        1135      6.46%
# 6                 Non-federal student loan         911      5.18%
# 7                             FHA mortgage         853      4.85%
# 8   Conventional adjustable mortgage (ARM)         800      4.55%
# 9                             Vehicle loan         721      4.10%
# 10              Other bank product/service         629      3.58%
# 11                             Payday loan         397      2.26%
#
# Número de datos únicos 43
# Número de datos faltantes 10574
#  --------------------------------------------------
#                                        Issue  Frecuencia Porcentaje
# 0     Incorrect information on credit report        4170     14.81%
# 1      Cont'd attempts collect debt not owed        3351     11.90%
# 2   Loan modification,collection,foreclosure        3049     10.83%
# 3   Loan servicing, payments, escrow account        2627      9.33%
# 4            Disclosure verification of debt        1300      4.62%
# 5                      Communication tactics        1251      4.44%
# 6    Account opening, closing, or management        1142      4.06%
# 7                   Deposits and withdrawals         690      2.45%
# 8   Credit reporting company's investigation         638      2.27%
# 9         False statements or representation         624      2.22%
# 10                Managing the loan or lease         590      2.10%
# 11  Unable to get credit report/credit score         584      2.07%
#
# Número de datos únicos 90
# Número de datos faltantes 2
#  --------------------------------------------------
#                                 Sub-issue  Frecuencia Porcentaje
# 0                        Debt is not mine        2125     16.09%
# 1                          Account status        1604     12.14%
# 2                 Information is not mine        1307      9.89%
# 3                           Debt was paid         890      6.74%
# 4    Not given enough info to verify debt         815      6.17%
# 5              Frequent or repeated calls         754      5.71%
# 6                           Account terms         484      3.66%
# 7       Attempted to collect wrong amount         482      3.65%
# 8    Right to dispute notice not received         387      2.93%
# 9   Problem getting my free annual report         386      2.92%
# 10                          Public record         356      2.69%
# 11  Talked to a third party about my debt         289      2.19%
#
# Número de datos únicos 47
# Número de datos faltantes 14945
#  --------------------------------------------------
#    State  Frecuencia Porcentaje
# 0     CA        3859     13.91%
# 1     FL        2592      9.35%
# 2     TX        2380      8.58%
# 3     NY        1846      6.66%
# 4     GA        1146      4.13%
# 5     NJ        1113      4.01%
# 6     PA        1055      3.80%
# 7     IL        1003      3.62%
# 8     OH         939      3.39%
# 9     VA         869      3.13%
# 10    MD         791      2.85%
# 11    NC         764      2.75%
#
# Número de datos únicos 60
# Número de datos faltantes 421
#  --------------------------------------------------
#     ZIP code  Frecuencia Porcentaje
# 0    76116.0          58      0.21%
# 1    33173.0          39      0.14%
# 2    33614.0          38      0.14%
# 3    85032.0          37      0.13%
# 4    60445.0          36      0.13%
# 5    22192.0          35      0.13%
# 6    95825.0          33      0.12%
# 7    29730.0          30      0.11%
# 8    20001.0          30      0.11%
# 9    77489.0          28      0.10%
# 10   92663.0          28      0.10%
# 11   63114.0          27      0.10%
#
# Número de datos únicos 9869
# Número de datos faltantes 280
#  --------------------------------------------------
#    Date received  Frecuencia Porcentaje
# 0     2015-01-27         668      2.37%
# 1     2015-01-28         657      2.33%
# 2     2015-01-23         634      2.25%
# 3     2015-02-11         634      2.25%
# 4     2015-02-25         633      2.25%
# 5     2015-02-18         620      2.20%
# 6     2015-02-04         617      2.19%
# 7     2015-01-21         616      2.19%
# 8     2015-02-09         608      2.16%
# 9     2015-01-26         607      2.16%
# 10    2015-01-22         606      2.15%
# 11    2015-02-02         603      2.14%
#
# Número de datos únicos 78
# Número de datos faltantes 0
#  --------------------------------------------------
#    Date sent to company  Frecuencia Porcentaje
# 0            2015-02-18         734      2.61%
# 1            2015-03-03         712      2.53%
# 2            2015-02-10         679      2.41%
# 3            2015-01-29         672      2.39%
# 4            2015-02-11         643      2.28%
# 5            2015-02-24         637      2.26%
# 6            2015-03-04         636      2.26%
# 7            2015-02-26         636      2.26%
# 8            2015-02-03         630      2.24%
# 9            2015-02-23         625      2.22%
# 10           2015-01-27         621      2.21%
# 11           2015-01-16         611      2.17%
#
# Número de datos únicos 78
# Número de datos faltantes 0
#  --------------------------------------------------
#                 Company  Frecuencia Porcentaje
# 0               Equifax        2049      7.28%
# 1              Experian        1940      6.89%
# 2            TransUnion        1525      5.42%
# 3       Bank of America        1518      5.39%
# 4           Wells Fargo        1430      5.08%
# 5        JPMorgan Chase        1272      4.52%
# 6              Citibank        1016      3.61%
# 7                 Ocwen         934      3.32%
# 8   Nationstar Mortgage         749      2.66%
# 9           Capital One         567      2.01%
# 10    GE Capital Retail         481      1.71%
# 11         U.S. Bancorp         429      1.52%
#
# Número de datos únicos 1534
# Número de datos faltantes 0
#  --------------------------------------------------
#                   Company response  Frecuencia Porcentaje
# 0          Closed with explanation       19381     68.83%
# 1  Closed with non-monetary relief        3593     12.76%
# 2                      In progress        2690      9.55%
# 3      Closed with monetary relief        1534      5.45%
# 4                           Closed         606      2.15%
# 5                Untimely response         352      1.25%
#
# Número de datos únicos 6
# Número de datos faltantes 0
#  --------------------------------------------------
#   Timely response?  Frecuencia Porcentaje
# 0              Yes       27444     97.47%
# 1               No         712      2.53%
#
# Número de datos únicos 2
# Número de datos faltantes 0
#  --------------------------------------------------
#   Consumer disputed?  Frecuencia Porcentaje
# 0                Yes        4708     78.39%
# 1                 No        1298     21.61%
#
# Número de datos únicos 3
# Número de datos faltantes 22150
#  --------------------------------------------------

# %% [markdown]
# **Obtengamos una vista general de nuestro DataFrame**

# %%
profile = ProfileReport(df, title="Profiling Report", explorative=True)
profile.to_file("profiling_report.html")

# %%
report = TableReport(df, title="Table Report")
report

# %% [markdown]
# ### Tabla de State y Codigos ZIP de US: "zip_code_database.csv"

# %% [markdown]
# El código ZIP (de la sigla en inglés "Zoning Improvement Plan") es un código postal que sirve para identificar áreas geográficas con fines de entrega de correo. Un código FIPS (de la sigla en inglés "Federal Information Processing Standard") es un código numérico utilizado por el gobierno de EE. UU. para identificar de manera única estados, condados y otras subdivisiones geográficas.
#
# Podemos verificar los códigos en el siguiente enlace (WEB): https://www.zip-codes.com

# %%
df_ZIPcode = pd.read_csv (path_data + "zip_code_database.csv", sep=",")
df_ZIPcode.head()
# Out:
#    zip      type  decommissioned primary_city acceptable_cities  \
# 0  501    UNIQUE               0   Holtsville               NaN
# 1  544    UNIQUE               0   Holtsville               NaN
# 2  601  STANDARD               0     Adjuntas               NaN
# 3  602  STANDARD               0       Aguada               NaN
# 4  603  STANDARD               0    Aguadilla             Ramey
#
#                                  unacceptable_cities state  \
# 0                           Internal Revenue Service    NY
# 1                           Internal Revenue Service    NY
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
#
#                 county             timezone area_codes world_region country  \
# 0       Suffolk County     America/New_York        631          NaN      US
# 1       Suffolk County     America/New_York        631          NaN      US
# 2   Adjuntas Municipio  America/Puerto_Rico   787, 939          NaN      US
# 3     Aguada Municipio  America/Puerto_Rico   787, 939          NaN      US
# 4  Aguadilla Municipio  America/Puerto_Rico   787, 939          NaN      US
#
#    latitude  longitude  irs_estimated_population
# 0     40.81     -73.04                       562
# 1     40.81     -73.04                         0
# 2     18.16     -66.72                         0
# 3     18.38     -67.18                         0
# 4     18.43     -67.15                         0

# %%
# Creamos df_zip seleccionando las columnas que nos interesan
df_zip = df_ZIPcode[['state','primary_city' ,'zip']]

# Renombramos algunas columnas
df_zip = df_zip.rename(columns={'state': 'State_ref' ,'primary_city': 'City_ref', 'zip': 'ZIP_ref'})

# Guardamos el archivo df_zip.csv
df_zip.to_csv(path_data + 'df_zip.csv', index=False, header=True)
df_zip.head()
# Out:
#   State_ref    City_ref  ZIP_ref
# 0        NY  Holtsville      501
# 1        NY  Holtsville      544
# 2        PR    Adjuntas      601
# 3        PR      Aguada      602
# 4        PR   Aguadilla      603
